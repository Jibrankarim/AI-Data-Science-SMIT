# %% [markdown]
# ## Topics: String Functions, Type Casting, Input, Operators, and If-Else (Nested)

# %% [markdown]
# ### 1. Ek string variable banayein jisme aapka full name ho, aur usse poora CAPITAL letters mein print karein.

# %%
# Write your code here
str = ("jibran karim")
print(str.upper())
# Out:
# JIBRAN KARIM

# %% [markdown]
# ### 2. User se unka fav fruit poochiye aur uski length (kitne characters hain) print karein.

# %%
# Write your code here
fav_friut = input("Enter your fav fruit")
print(len(fav_friut))
# Out:
# Enter your fav fruit biryani
# 7

# %% [markdown]
# ### 3. Ek sentence likhiye 'Python is fun' aur 'fun' ko 'awesome' se replace karke print karein.

# %%
# Write your code here
str = ("python is fun")
print(str.replace("fun","awesome"))
# Out:
# python is awesome

# %% [markdown]
# ### 4. Check karein ke string 'Hello World' mein 'World' kaunse index par start hota hai.

# %%
# Write your code here
str =("hello world")
print(str.index("world"))
# Out:
# 6

# %% [markdown]
# ### 5. User se unka email address lein aur usse hamesha small letters (lowercase) mein convert karke dikhayein.

# %%
# Write your code here
strn =  input("Enter your email")
print(strn.lower())
# Out:
# Enter your email HFJJFJJFJF
# hfjjfjjfjf

# %% [markdown]
# ### 6. Ek sentence '   Python Programming   ' banayein aur uske extra spaces (suru aur aakhir ke) remove karein.

# %%
# Write your code here
str= ("     Python Programming    ")
print(str.strip())
# Out:
# Python Programming

# %% [markdown]
# ### 7. Ek string 'Welcome to coding' mein count karein ke 'o' letter kitni baar aaya hai.

# %%
# Write your code here
str=("Welcome to coding")
print(str.count("o"))
# Out:
# 3

# %% [markdown]
# ### 8. User se unki age input lein aur usse integer mein convert karke print karein.

# %%
# Write your code here
age = (input("Enter your Age"))
age = int (age)
print(age)
# Out:
# Enter your Age 26
# 26

# %% [markdown]
# ### 9. Ek float value '15.99' ko integer mein convert karein. Output kya aaya?

# %%
# Write your code here
num = float (15.88)
num = int(num)
print(num)
# Out:
# 15

# %% [markdown]
# ### 10. Do numbers ko input lein, dono ko add karein, lekin dhayan rahe input hamesha string hota hai, isliye unhe cast karein.

# %%
# Write your code here
num1 = int(input("Enter first Numnber"))
num2 = int(input("Enter second Numnber"))

add = num1 + num2

print(add)
# Out:
# Enter first Numnber 8
# Enter second Numnber 2
# 10

# %% [markdown]
# ### 11. Ek integer 100 ko string mein convert karein aur check karein ke uska type ab 'str' hai ya nahi.

# %%
# Write your code here
num = 100

text = str(num)

print(text)
print(type(text))
# Out:
# 100
# <class 'str'>

# %% [markdown]
# ### 12. User se price lein (e.g., 99.5) aur usse integer mein badal kar dikhayein.

# %%
# Write your code here
price = float(input("Enter price in float (eg: 33.5): "))

price = int(price)
print(price)
# Out:
# Enter price in float (eg: 33.5):  55.8
# 55

# %% [markdown]
# ### 13. Ek string '10' aur doosri string '20' ko add (concatenate) karne ki jagah math wala addition (30) karke dikhayein.

# %%
# Write your code here
num1 = "10"
num2 = "20"

add = int(num1) + int(num2) 
print(add)
# Out:
# 30

# %% [markdown]
# ### 14. Ek variable mein '50.5' save karein aur usse float mein cast karne ke baad 10 plus karein.

# %%
# Write your code here
no = 50.5 

no = float(no)

add = no + 10 
print(add)
# Out:
# 60.5

# %% [markdown]
# ### 15. User se uska naam aur shehar (city) ka naam poochiye aur ek sentence print karein: 'Hello [Name], welcome to [City]'.

# %%
# Write your code here
name = input("Enter your name ")
city = input("Enter your city")

print(f"Hello {name} welcome to {city}")
# Out:
# Enter your name  jibran
# Enter your city hunza
# Hello jibran welcome to hunza

# %% [markdown]
# ### 16. User se do numbers lein aur unka product (multiply) print karein.

# %%
# Write your code here
num1 = int(input("Enter your first number"))
num2 = int(input("Enter your second number"))

multiple = num1 * num2 

print("product is:",multiple)
# Out:
# Enter your first number 4
# Enter your second number 2
# product is: 8

# %% [markdown]
# ### 17. User se unka favorite color poochiye aur print karein: 'I also like [color]'.

# %%
# Write your code here
colour = input("Enter your favorite color:")

print(f"I also like {colour}")
# Out:
# Enter your favorite color: red
# I also like red

# %% [markdown]
# ### 18. Ek chota program banayein jo user se uska birth year le aur uska current age calculate karein.

# %%
# Write your code here
birth = int (input("Enter your birth year"))

current_year = 2026
age = current_year - birth 

print(age)
# Out:
# Enter your birth year 1999
# 27

# %% [markdown]
# ### 19. User se ek word input lein aur usse 5 baar print karein (string multiplication use karke).

# %%
# Write your code here
user = input ("Enter any word")

mult = user * 5

print(mult)
# Out:
# Enter any word jibran
# jibranjibranjibranjibranjibran

# %% [markdown]
# ### 20. User se unka mobile number lein (as string) aur unhe batayein ke unhone kya number type kiya hai.

# %%
# Write your code here
mobile_no = input("Enter your mobile number:")

print(f"your mobile number is:{mobile_no}", type(mobile_no))
# Out:
# Enter your mobile number: 034085836255
# your mobile number is:034085836255 <class 'str'>

# %% [markdown]
# ### 21. Do variables lein a=10, b=3. Inka remainder (modulo) nikal kar dikhayein.

# %%
# Write your code here
a = 10
b = 3

modulo = a % b 

print(modulo)
# Out:
# 1

# %% [markdown]
# ### 22. Check karein ke 15, 10 se bada hai AUR 20 se chota hai (Logical AND operator).

# %%
# Write your code here
a = 15 
b = 10 
c = 20

num = (a > b and c > a)

print(num)
# Out:
# True

# %% [markdown]
# ### 23. User se ek number lein aur check karein ke wo 100 se bada hai ya nahi (Comparison operator).

# %%
# Write your code here

number = int(input("Enter number: "))

check = number > 100 
print( check )
# Out:
# Enter number:  20
# False

# %% [markdown]
# ### 24. 2 ki power 5 (2^5) calculate karke print karein.

# %%
# Write your code here
num = int(2**5)
print(num)
# Out:
# 32

# %% [markdown]
# ### 25. Check karein ke kya 50, 100 ke barabar hai (Equal to operator).

# %%
# Write your code here
num = 50 == 100 

print(num)
print(type(num))
# Out:
# False
# <class 'bool'>

# %% [markdown]
# ### 26. Do Boolean values (True, False) lein aur 'OR' operator ka result dikhayein.

# %%
# Write your code here
first_value = True  
second_value = False 

result = first_value or second_value 

print(result)
# Out:
# True

# %% [markdown]
# ### 27. User se ek number lein aur check karein ke wo Positive hai ya Negative.

# %%
# Write your code here
num = int(input("Enter number"))

if num > 0:
    print("your number is positive")
elif num < 0:
    print("your number is negative")
else:
    print("enter number please")
# Out:
# Enter number -9
# your number is negative

# %% [markdown]
# ### 28. Check karein ke user ki age 18 se zyada hai ya nahi, agar hai toh print 'Eligible for Vote'.

# %%
# Write your code here
age = int(input("Enter your Age please:"))
if age >= 18:
    print("Eligible for vote")
else:
    print("Sorry not Eligible")
# Out:
# Enter your Age please: 45
# Eligible for vote

# %% [markdown]
# ### 29. Ek number input lein aur check karein ke wo Even hai ya Odd.

# %%
# Write your code here
num = int(input("Enter number to find Even or Odd"))

if num % 2 == 0:
    print("your number is even")
else:
    print("your number is odd")
# Out:
# Enter number to find Even or Odd 5
# your number is odd

# %% [markdown]
# ### 30. User se do numbers lein aur batayein dono mein se bada (Greater) kaunsa hai.

# %%
# Write your code here
num1 = input("Enter first number:")
num2 = input("Enter second number:")

if num1 > num2:
    print(f" your first number {num1}  Is greater")
elif num2 > num1:
    print(f"your second number {num2}  Is greater ")
# Out:
# Enter first number: 5
# Enter second number: 8
# your second number 8  Is greater

# %% [markdown]
# ### 31. Ek student ke marks input lein. Agar marks 33 se zyada hain toh 'Pass', warna 'Fail'.

# %%
# Write your code here
student_marks = float(input("Enter your marks:"))

if student_marks >= 33:
    print(" pass")
elif student_marks < 33:
    print("Fail")
# Out:
# Enter your marks: 33
#  pass

# %% [markdown]
# ### 32. Check karein ke user ne jo string input ki hai wo empty toh nahi hai.

# %%
# Write your code here
user = input("enter string")
if user == "" :
    print("empty")
else:
    print("Not empty")
# Out:
# enter string f
# Not empty

# %% [markdown]
# ### 33. User se ek password input lein. Agar password 'python123' hai toh 'Access Granted', warna 'Wrong Password'.

# %%
# Write your code here
password = (input("Enter your password:"))
if password == "python123":
    print("Access Granted")
else:
    print("wrong password")
# Out:
# Enter your password: python123
# Access Granted

# %% [markdown]
# ### 34. Check karein ke user ka input kiya hua number zero hai ya nahi.

# %%
# Write your code here
num = int(input("Enter number 0 to 5:"))
if num == 0:
    print(" yes! zero ")
else:
    print("not zero")
# Out:
# Enter number 0 to 5: 02
# not zero

# %% [markdown]
# ### 35. Student Grading System: 90+ (A), 80-89 (B), 70-79 (C), below 70 (D).

# %%
# Write your code here
grading = float(input("Enter your marks:"))
if grading >= 90 and grading <= 100:
    print("A")
elif grading >= 80 and grading <= 89:
    print("B")
elif grading >= 70 and grading <= 79:
    print("C")
elif grading < 70:
    print("D")
else:
    print("wrong input")

# %% [markdown]
# ### 36. User se temperature lein. Agar 30 se zyada hai toh 'Hot', 15-30 hai toh 'Warm', 15 se niche hai toh 'Cold'.

# %%
# Write your code here
temperature = float(input("Enter temperature: "))
if temperature > 30:
    print("Temperature is Hot")
elif temperature >= 15 and temperature <= 30:
    print ("Temperature is Warm ")
elif temperature < 15:
    print("Cold")
else:
    print("Enter temperature plaese")
# Out:
# Enter temperature:  7
# Cold

# %% [markdown]
# ### 37. Ek number check karein ke wo 3 se divisible hai, 5 se divisible hai, ya dono se (FizzBuzz logic).

# %%
# Write your code here
num = int(input("Enter Number: "))
if num % 3 == 0 and num % 5 == 0:
    print(" Number is divisible by both 3 and 5 ")
elif num % 3 == 0:
    print("Number divisible by 3: ")
elif num % 5 == 0:
    print("Number divisible by 5 ")
else: 
    print("not divisible")
# Out:
# Enter Number:  45
#  Number is divisible by both 3 and 5

# %% [markdown]
# ### 38. User se ek character lein aur check karein ke wo Vowel (a, e, i, o, u) hai ya Consonant.

# %%
# Write your code here
character = (input("Enter character: "))
if character in "aeiouAEIOU"  :
    print("This character is vowal")
else:
    print("Not vowal")
# Out:
# Enter character:  l
# Not vowal

# %% [markdown]
# ### 39. Bill Calculator: Agar shopping 5000 se upar hai toh 20% discount, 2000-5000 par 10% discount, warna No discount.

# %%
# Write your code here
bill = float (input("Enter your totall bill"))
if bill > 5000:
    print("20% discount")
elif bill >= 2000 or bill >= 5000:
    print("10% discount")
else:
    print("sorry no discount")
# Out:
# Enter your totall bill 5000
# 10% discount

# %% [markdown]
# ### 40. Ek person ki age check karein: 0-12 (Child), 13-19 (Teenager), 20-59 (Adult), 60+ (Senior Citizen).

# %%
# Write your code here
age = int(input("Enter your age "))
if age <=12:
    print("Child")
elif age >= 13 and age <=19:
    print("Teenager")
elif age >= 20 and age <=59:
    print("Adult")
elif age >= 60:
    print("senior citizen")
# Out:
# Enter your age  60
# senior citizen

# %% [markdown]
# ### 41. Check karein ke ek saal (year) Leap Year hai ya nahi.

# %%
# Write your code here
year = int(input("Enter a year: "))

if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    print("Leap Year")

else:
    print("Not a Leap Year")
# Out:
# Enter a year:  400
# Leap Year

# %% [markdown]
# ### 42. User se week number (1-7) lein aur corresponding day (Monday, Tuesday...) print karein.

# %%
# Write your code here
week = int (input("Enter number from 1 to 7 to find day:"))
if week == 1:
    print("Monday")
elif week == 2:
    print("Tuesday")
elif week == 3:
    print("wednesday")
elif week == 4:
    print("Thursday")
elif week == 5:
    print("Friday")
elif week == 6:
    print("Saturday")
elif week == 7:
    print("Sunday")
else:
    print("wrong input")
# Out:
# Enter number from 1 to 7 to find day: 8
# wrong input

# %% [markdown]
# ### 43. Ek simple calculator banayein (+, -, *, /) symbols ke basis par operation perform karein.

# %%
# Write your code here
num1 = float (input("Enter first numbers for calculate:"))
num2 = float (input("Enter second numbers for calculate:"))
calculator = (input("Enter operator +,-,*,/"))

if calculator == "+":
    print("Result:", num1 + num2)
elif calculator == "-":
    print("Result:", num1 - num2)
elif calculator == "*":
    print("Result:", num1 * num2)
elif calculator == "/":
    print("Result:", num1 / num2)
else:
    print("something wrong")
# Out:
# Enter first numbers for calculate: 5
# Enter second numbers for calculate: 4
# Enter operator +,-,*,/ *
# Result: 20.0

# %% [markdown]
# ### 44. User ka weight aur height le kar BMI category batayein (Underweight, Normal, Overweight).

# %%
# Write your code here
weight = float (input("Enter your weight in (kg): "))
height = float (input("Enter your height in (meter): "))

bim = weight / (height * height)

print("Your BMI is: ")

if bim < 18.5:
    print("Category underweight")
elif bim < 25:
    print ("Category Normal")
elif bim < 30:
    print("Category Overweight")
else:
    print("Enter your weight and height!")
# Out:
# Enter your weight in (kg):  81
# Enter your height in (meter):  1.75
# Your BMI is:
# Category Overweight

# %% [markdown]
# ### 45. ATM Machine Logic: Pehle PIN check karein, agar sahi ho toh Amount poochiye, agar account balance se kam amount ho toh 'Withdrawal Success'.

# %%
##### Write your code here
bank_amount = 10000
atm_pin =  (input("Enter your PIN: "))


if atm_pin == "1234python":
    print(" checked PIN ")

    amount = float (input("Enter your amount: "))
    if amount <= bank_amount:
        print ("Withdrawal success")
    else:
        print("Insufficient Balance")

else:
    print("yor pin is incorrect")
# Out:
# Enter your PIN:  1234python
#  checked PIN
# Enter your amount:  10000000
# lass balance

# %% [markdown]
# ### 46. Login System: Pehle Username check karein, agar match ho tabhi Password check karein.

# %%
# Write your code here
user = (input("Enter username: "))

if user == "jibran karim":
    print("checked username")
    
    user_password = (input("Enter user password: "))
    
    if user_password == "jibran1234":
        print("checked password ")
        
    else:
        print("incorrect password")
        
else:
    print("incorrect user name ")

# %% [markdown]
# ### 47. Largest of Three: User se 3 numbers lein aur nested if-else use karke sabse bada number dhoondein.

# %%
# Write your code here
num1 = int (input ("Enter first number to find largest of three numbers:"))
num2 = int (input ("Enter second number to find largest of three numbers:"))
num3 = int (input ("Enter third number to find largest of three numbers:"))

if num1 > num2:
    if num1 > num3:
        print(f"{num1} is largest number")
    else:
        print(f"{num3} is largest number")

    if num2 > num1:
        print(f"{num2} is largest number")
else:
    print(f"{num3} is largest number")

# %% [markdown]
# ### 48. Ticket Booking: Pehle age check karein. Agar 18+ hai toh check karein 'Do you have ID?'. Agar ID hai toh 'Ticket Issued'.

# %%
# Write your code here
age = int(input("Enter your Age: "))

if age >= 18:
    
    nic = input(" Do you have ID? (Yes or No )")
   
    
    if nic == "Yes" or nic == "YES" or nic == "yes":
        print("Ticket issued")
    else:
        print("ID required")
else:
    print("we are sorry you are under age")
# Out:
# Enter your Age:  5
# we are sorry you are under age

# %% [markdown]
# ### 49. Admission System: Agar student ke marks 80+ hain, toh check karein unka interview clear hai ya nahi. Dono clear hone par 'Admission Done'.

# %%
# Write your code here
student_marks = float(input("Enter your marks: "))
if student_marks >=80:
    
    interview = input("Did you clear interview ? (Yes or No)") 
    
    if interview == "yes" or interview == "YES" or interview == "Yes": 
        print("your Admission Done")
        
    else:
        print("sorry try next time")

else:
    print("sorry your marks is not 80+ ")
# Out:
# Enter your marks:  85
# Did you clear interview ? (Yes or No) no
# sorry try next time

# %% [markdown]
# ### 50. Number Range: Check karein number positive hai ya nahi. Agar positive hai, toh check karein wo 100 se bada hai ya chota.

# %%
# Write your code here
num = float(input("Enter number: "))

if num > 0:
    print("number is positive")
    if num > 100:
        print(f"{num} is Greater then 100. ")
    else: 
        print(f"{num} is Less then 100. ")
else:
    print("number is not positive")
# Out:
# Enter number:  44
# number is positive
# 44.0 is Less then 100.

# %% [markdown]
# ### 51. Restaurant Order: Pehle Veg ya Non-Veg poochein. Veg mein Paneer ya Dal, Non-Veg mein Chicken ya Mutton ka option dein.

# %%
# Write your code here
order = input("Enter your order (Veg or NonVeg:) ")

if order == "Veg" or order == "VEG" or order == "veg":
    
    veg = input ("Paneer or Dal: ")
    
    if veg == "Paneer" or veg == "paneer" or veg == "PANEER":
        print(f"your {veg} order is Done ")
        
    elif veg == "dal" or veg == "Dal" or veg == "DAL":
        print(f"Your {veg} order is Done")
        
    else:
        print("plase enter a veg order")
        
elif order == "NonVeg" or order == "nonveg" or order == "NONVEG":
    
    nonveg = input ("Chicken or Mutton: ") 

    if nonveg == "chicken" or nonveg == "Chicken" or nonveg == "CHICKEN" :
        print(f"Your {nonveg} order is Done")

    elif nonveg == "MUTTON" or nonveg == "Mutton" or nonveg == "mutton":
        print(f"Your {nonveg} order is Done")

    else:
        print("please enter nonveg order")

else:
    print("something wrong")

# %% [markdown]
# ### 52. Ek number input lein aur check karein ke wo Single digit hai, Double digit ya Triple digit.

# %%
# Write your code here
num = int(input("Enter number from (0 to 999)"))

if num >= 0 and num <=9:
    print(f"{num} Number is single digit")
elif num >= 10 and num <= 99:
    print(f"{num} Number is Double digit ")
elif num >= 100 and num <= 999:
    print(f"{num }Number is Triple digit ")

else:
    print("Wrong input")
# Out:
# Enter number from (0 to 999) 555
# 555Number is Triple digit

# %% [markdown]
# ### 53. User se salary aur service years lein. Agar service 5 saal se zyada hai toh 5% bonus calculate karke final salary batayein.

# %%
# Write your code here
salary = float(input("Enter your salary: "))
service = float(input("Enter your service years: "))

if service > 5: 
    bonus = salary * 0.05
    final_salary = bonus + salary
    print(f"Your final salary is: {final_salary}")
else:
    print(" Sorry! No bonus")
# Out:
# Enter your salary:  50000
# Enter your service years:  6
# Your final salary is: 52500.0

# %% [markdown]
# ### 54. Ek triangle ki teen sides input lein aur batayein ke wo Equilateral, Isosceles ya Scalene hai.

# %%
# Write your code here
size1 = float(input("Enter your first side "))
size2 = float(input("Enter your second side "))
size3 = float(input("Enter your third  side "))

if size1 == size3 and size1 == size2:
    print("Equilater")
elif size1 == size2 or size1 == size3 or size2 == size3:
    print("Isosceles")
else:
    print("Scalene")
# Out:
# Enter your first side  4
# Enter your second side  4
# Enter your third  side  4
# Equilater

# %% [markdown]
# ### 55. Month name check karke batayein ke us month mein kitne days hote hain (Jan, Feb...).

# %%
# Write your code here
month = input("Enter month name: ").strip().lower()

if month == "january" or month == "march" or month == "may" or month == "july" or month == "august" or month == "october" or month == "december":
    print( "31 days.")
elif month == "february":
    print("28 or 29 days")
elif month == "april" or month == "june" or month == "september" or month == "nevember":
    print("30 days. ")

else:
    print("Invalid month name ")
# Out:
# Enter month name:  MAY
# 31 days.

# %% [markdown]
# ### 56. Nested If-Else se check karein ke ek number Even hai aur 50 se bada hai, ya Even hai aur 50 se chota hai.

# %%
# Write your code here

num = int(input("Enter number: "))

if num % 2 == 0:
    if num > 50:
        print(f" Your {num}  is even number is greater then 50 ")
    else:
        print(f"{num} is even and less then 50")
else:
    print(f"{num}  is no even")
# Out:
# Enter number:  71
# 71  is no even

# %% [markdown]
# ### 57. Student Result: Maths aur Science dono mein 40+ hone chahiye pass hone ke liye. Agar ek mein kam hain toh batayein kaunsa subject weak hai.

# %%
# Write your code here

maths = int(input("Enter Maths marks: "))
science = int(input("Enter Science marks: "))

if maths >= 40:

    if science >= 40:
        print("You are pass in both subjects")

    else:
        print("You are weak in Science")

else:

    if science >= 40:
        print("You are weak in Maths")

    else:
        print("You are fail in both subjects")
# Out:
# Enter Maths marks:  62
# Enter Science marks:  45
# You are pass in both subjects

# %% [markdown]
# ### 58. Electricity Bill: Pehle 100 units free, next 100 units Rs 5/unit, uske baad Rs 10/unit.

# %%
# Write your code here
units = float (input("Enter your electricity units: "))

if units <= 100:
    print(f"{units} units free")

else:
    if units <= 200:
        bill = (units - 100) * 5
        print(f"Your bill is Rs: {bill}")

    else:
        
        bill = 500 + (units - 200) * 10
        print(f"Your bill is Rs: {bill}")
# Out:
# Enter your electricity units:  700
# Your bill is Rs: 5500.0

# %% [markdown]
# ### 59. Game Level: Score 0-50 (Beginner), 51-100 (Intermediate). Agar Intermediate hai toh check karein user ne boss level par kiya hai ya nahi.

# %%
# Write your code here
game = float(input("Enter your Score: "))

if game <= 50:
    print("Beginner")

if game >= 51 or game <= 100:
    print("Intermediate")

boss = input("Did you clear boss level (yes or no): ").lower()

if boss == "yes":
    print("Boss level cleared")

else:
    print("Boss level not cleared")
# Out:
# Enter your Score:  55
# Intermediate
# Did you clear boss level (yes or no):  yes
# Boss level cleared

# %% [markdown]
# ### 60. Final Challenge: Ek mini-project logic banayein jisme user se Username, Password, aur ek Security Question poochein nested loops aur if-else ke saath.

# %%
# Write your code here
while True:

    username = input("Enter username: ")
    password = input("Enter password: ")

    if username == "jibran":

        if password == "python1234":

            answer = input("What is your favourite color? ").lower()

            if answer == "red":
                print("Access Granted")
                break

            else:
                print("Wrong security answer")

        else:
            print("Wrong password")

    else:
        print("Wrong username")
# Out:
# Enter username:  jibran
# Enter password:  python1234
# What is your favourite color?  blue
# Access Granted
